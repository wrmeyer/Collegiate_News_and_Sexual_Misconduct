# %%
import pandas as pd
import os
location = str(os.getcwd())

# %%
f = (location[:-8] + "Articles\\articles_cleaned.csv")
articles = pd.read_csv(f)
articles = articles.to_dict("index")

# %%
f = (location[:-8] + "Tweets\\tweets_cleaned.csv")
tweets = pd.read_csv(f)
tweets = tweets.to_dict("index")

# %%
locations = ["IUB", "UMD", "UMN", "Stanford", "Wisconsin"]

from datetime import date, timedelta
sdate = date(2000,1,1)   # start date
edate = date(2022,1,2)   # end date

unformatted_dates = pd.date_range(sdate,edate-timedelta(days=1),freq='d').tolist()

dates = []
for item in unformatted_dates:
    y = str(item.year)
    if (item.day) < 10:
        d = "0"+str(item.day)
    else:
        d = str(item.day)
    if (item.day) < 10:
        m = "0"+str(item.month)
    else:
        m = str(item.month)
    dates.append(m +"/"+ d +"/"+ y)
print(len(dates))
# Out:
# 8037

# %%
by_date = []

for location in locations:
    print(location)
    k = 0
    for date in dates:
        date_dict = {}
        date_dict["location"] = location
        date_dict["date"] = date
        tweet_count = 0
        article_count = 0

        for i in range(len(tweets)):
            tweet = tweets[i]
            if date == tweet["created_at"] and tweet["location"] == location:
                tweet_count += 1

        for j in range(len(articles)):
            article = articles[j]
            if date == article["date"] and article["location"] == location:
                article_count += 1
        
            
        date_dict["tweet_count"] = tweet_count
        date_dict["article_count"] = article_count

        by_date.append(date_dict)
        k += 1
                                           
pd.DataFrame(by_date)
# Out:
# IUB
# UMD
# UMN
# Stanford
# Wisconsin
#         location        date  article_coverage  tweet_coverage  tweet_count  \
# 0            IUB  01/01/2000          0.000000        0.000000            0
# 1            IUB  01/02/2000          0.000000        0.000000            0
# 2            IUB  01/03/2000          0.000000        0.000000            0
# 3            IUB  01/04/2000          0.000000        0.000000            0
# 4            IUB  01/05/2000          0.000000        0.000000            0
# ...          ...         ...               ...             ...          ...
# 40180  Wisconsin  12/28/2021          1.184388        0.147788            0
# 40181  Wisconsin  12/29/2021          1.105428        0.098525            0
# 40182  Wisconsin  12/30/2021          1.031733        0.065683            0
# 40183  Wisconsin  12/31/2021          0.962951        0.043789            0
# 40184  Wisconsin  01/01/2022          0.898754        0.029193            0
#
#        article_count
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 40180              0
# 40181              0
# 40182              0
# 40183              0
# 40184              0
#
# [40185 rows x 6 columns]

# %%
pd.DataFrame(by_date).to_csv('counts_by_day.csv')

# %% [markdown]
# Average for each day across all years to check for seasonality (Average between 2011 and end of 2021)

# %%
location = str(os.getcwd())
f = (location + "\counts_by_day.csv")
by_dates = pd.read_csv(f)
by_dates = by_dates.to_dict("records") 

pd.DataFrame(by_dates)
# Out:
#         location        date  hl_tweets  hl_articles   ...1  article_coverage  \
# 0            IUB  2000-01-01   0.000000     0.000000      0          0.000000
# 1            IUB  2000-01-02   0.000000     0.000000      1          0.000000
# 2            IUB  2000-01-03   0.000000     0.000000      2          0.000000
# 3            IUB  2000-01-04   0.000000     0.000000      3          0.000000
# 4            IUB  2000-01-05   0.000000     0.000000      4          0.000000
# ...          ...         ...        ...          ...    ...               ...
# 37210  Wisconsin  2021-12-28   0.349115     1.775257  40180          1.184388
# 37211  Wisconsin  2021-12-29   0.277106     1.688676  40181          1.105428
# 37212  Wisconsin  2021-12-30   0.219950     1.606319  40182          1.031733
# 37213  Wisconsin  2021-12-31   0.174583     1.527978  40183          0.962951
# 37214  Wisconsin  2022-01-01   0.138574     1.453457  40184          0.898754
#
#        tweet_coverage  tweet_count  article_count
# 0            0.000000            0              0
# 1            0.000000            0              0
# 2            0.000000            0              0
# 3            0.000000            0              0
# 4            0.000000            0              0
# ...               ...          ...            ...
# 37210        0.147788            0              0
# 37211        0.098525            0              0
# 37212        0.065683            0              0
# 37213        0.043789            0              0
# 37214        0.029193            0              0
#
# [37215 rows x 9 columns]

# %%
from datetime import date, timedelta

start_date = date(1999, 1, 1) 
end_date = date(1999, 12, 31)    # perhaps date.now()

delta = end_date - start_date   # returns timedelta
dates = []
for i in range(delta.days + 1):
    day = start_date + timedelta(days=i)
    dates.append(day)
len(dates)
# Out:
# 365

# %%
df = []
locations = ["IUB", "UMD", "UMN", "Stanford", "Wisconsin"]
for location in locations:
    for date in dates:
        date = str(date)
        comp_day = date.split("-")[1] + "/" +  date.split("-")[2]

        total_tweets = 0
        total_articles = 0
        hl_articles = 0
        hl_tweets = 0
        for day in by_dates:
            full = str(day["date"])
            if str(full) != "nan" and int(full.split("-")[0]) > 2010 and int(full.split("-")[0]) < 2022:
                
                m = full.split("-")[1]
#                 if int(m) < 10:
#                     m = "0"+m
                d = full.split("-")[2]
#                 if int(d) < 10:
#                     d = "0"+d
                md = m + "/" + d
                
                if comp_day == md and location == day["location"]:
                    total_articles += day["tweet_count"]
                    total_tweets += day["article_count"]
                    hl_articles += day["hl_articles"]
                    hl_tweets += day["hl_tweets"]
                    
        average_tweets = total_tweets/11
        average_articles = total_articles/11
        average_hl_tweets = hl_tweets/11
        average_hl_articles = hl_articles/11
        df.append({"date":date, "average_tweets": average_tweets, "average_articles": average_articles, "location": location, "hl_tweets": average_hl_tweets, "hl_articles": average_hl_articles})

pd.DataFrame(df)
# Out:
#             date  average_tweets  average_articles   location  hl_tweets  \
# 0     1999-01-01        0.000000          0.000000        IUB   0.060564
# 1     1999-01-02        0.000000          0.000000        IUB   0.048072
# 2     1999-01-03        0.000000          0.000000        IUB   0.038157
# 3     1999-01-04        0.000000          0.000000        IUB   0.030286
# 4     1999-01-05        0.000000          0.000000        IUB   0.024039
# ...          ...             ...               ...        ...        ...
# 1820  1999-12-27        0.090909          0.363636  Wisconsin   1.658196
# 1821  1999-12-28        0.000000          0.363636  Wisconsin   1.679812
# 1822  1999-12-29        0.000000          0.272727  Wisconsin   1.606061
# 1823  1999-12-30        0.090909          0.636364  Wisconsin   1.911157
# 1824  1999-12-31        0.000000          0.000000  Wisconsin   1.516961
#
#       hl_articles
# 0        2.373536
# 1        2.257777
# 2        2.147664
# 3        2.042921
# 4        1.943287
# ...           ...
# 1820     2.630250
# 1821     2.501971
# 1822     2.379949
# 1823     2.354786
# 1824     2.239942
#
# [1825 rows x 6 columns]

# %%
pd.DataFrame(df).to_csv('yearly_averages.csv')
